# %% [markdown]
# **Code Example 1: Sobel Edge Detection**

# %%
# Install OpenCV in Colab
# !pip install opencv-python-headless --quiet

# Import required libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# Step 1: Upload image
print("Upload a road or lane image:")
uploaded = files.upload()

# Get uploaded file path
image_path = list(uploaded.keys())[0]

# Step 2: Read image in grayscale
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if image loaded correctly
if img is None:
    raise ValueError("Image not loaded properly. Please upload a valid image.")

# Step 3: Apply Sobel operator
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=3)   # Horizontal edges
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=3)   # Vertical edges

# Calculate gradient magnitude
sobel_magnitude = cv2.magnitude(sobelx, sobely)

# Normalize result for display
sobel_norm = np.uint8(255 * sobel_magnitude / np.max(sobel_magnitude))

# Step 4: Display original and edge-detected image
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title("Original Grayscale Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(sobel_norm, cmap='gray')
plt.title("Sobel Edge Detection")
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Upload a road or lane image:
#      <input type="file" id="files-6b0e30a6-9330-4670-bcf1-899e9e981021" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b0e30a6-9330-4670-bcf1-899e9e981021">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# **Code Example 2: Prewitt Edge Detection**

# %%
# Install OpenCV in Colab
# !pip install opencv-python-headless --quiet

# Import required libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# Step 1: Upload aerial or satellite image
print("Upload an aerial or satellite image:")
uploaded = files.upload()

# Get uploaded file path
image_path = list(uploaded.keys())[0]

# Step 2: Read image in grayscale
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if image loaded correctly
if img is None:
    raise ValueError("Image not loaded properly. Please upload a valid image.")

# Step 3: Define Prewitt kernels
kernelx = np.array([
    [1, 0, -1],
    [1, 0, -1],
    [1, 0, -1]
], dtype=np.float32)

kernely = np.array([
    [1, 1, 1],
    [0, 0, 0],
    [-1, -1, -1]
], dtype=np.float32)

# Step 4: Apply Prewitt filter
img_prewittx = cv2.filter2D(img, -1, kernelx)
img_prewitty = cv2.filter2D(img, -1, kernely)

# Combine horizontal and vertical edges
prewitt = cv2.addWeighted(img_prewittx, 0.5, img_prewitty, 0.5, 0)

# Step 5: Display results
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title("Original Grayscale Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(prewitt, cmap='gray')
plt.title("Prewitt Edge Detection")
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Upload an aerial or satellite image:
#      <input type="file" id="files-e9b47dcf-1157-49db-a998-50eb828a9830" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9b47dcf-1157-49db-a998-50eb828a9830">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# **Code Example 3: Canny Edge Detection**

# %%
# Install OpenCV in Colab
# !pip install opencv-python-headless --quiet

# Import required libraries
import cv2
import matplotlib.pyplot as plt
from google.colab import files

# Step 1: Upload image
print("Upload an image of a traffic sign or street scene:")
uploaded = files.upload()

# Get uploaded file path
image_path = list(uploaded.keys())[0]

# Step 2: Read image in grayscale
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if image loaded correctly
if img is None:
    raise ValueError("Image not loaded properly. Please upload a valid image.")

# Step 3: Apply Canny edge detector
edges = cv2.Canny(img, threshold1=100, threshold2=200)

# Step 4: Display original and edge-detected image
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title("Original Grayscale Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(edges, cmap='gray')
plt.title("Canny Edge Detection")
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Upload an image of a traffic sign or street scene:
#      <input type="file" id="files-80c5b2ac-40f1-4686-94df-4de39211bdc2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80c5b2ac-40f1-4686-94df-4de39211bdc2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %% [markdown]
# **Case Study 1: Medical Image Edge Detection (CT/MRI Scans)**

# %%
# Install OpenCV in Colab
# !pip install opencv-python-headless --quiet

# Import required libraries
import cv2
import matplotlib.pyplot as plt
from google.colab import files

# Step 1: Upload medical image
print("Upload a grayscale medical image (CT or MRI):")
uploaded = files.upload()

# Get uploaded file path
img_path = list(uploaded.keys())[0]

# Step 2: Read image in grayscale
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

# Check if image loaded correctly
if img is None:
    raise ValueError("Image not loaded properly. Please upload a valid CT/MRI image.")

# Step 3: Apply Canny edge detection
edges = cv2.Canny(img, 50, 150)

# Step 4: Display original and edge-detected image
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title("Original Medical Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(edges, cmap='gray')
plt.title("Canny Edge Detection")
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Upload a grayscale medical image (CT or MRI):
#      <input type="file" id="files-afd51e29-294c-48ad-a4e8-844398cdbd33" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-afd51e29-294c-48ad-a4e8-844398cdbd33">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %% [markdown]
# **Case Study 2: Road and Lane Detection in Autonomous Vehicles**

# %%
# Install OpenCV in Colab
# !pip install opencv-python-headless --quiet

# Import required libraries
import cv2
import matplotlib.pyplot as plt
from google.colab import files

# Step 1: Upload road image
print("Upload a road image with visible lane lines:")
uploaded = files.upload()

# Get uploaded file path
img_path = list(uploaded.keys())[0]

# Step 2: Read image
img = cv2.imread(img_path)

# Check if image loaded correctly
if img is None:
    raise ValueError("Image not loaded properly. Please upload a valid road image.")

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Step 3: Apply Gaussian Blur
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Step 4: Apply Canny edge detection
edges = cv2.Canny(blurred, 50, 150)

# Step 5: Display results
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(gray, cmap='gray')
plt.title("Original Grayscale Road Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(edges, cmap='gray')
plt.title("Canny Edge Detection")
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Upload a road image with visible lane lines:
#      <input type="file" id="files-4b9dcf6a-da67-4aff-b978-c2e4191621c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b9dcf6a-da67-4aff-b978-c2e4191621c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
